# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#question 1

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Pregnancies', kde=True)
plt.title('Distribution of Pregnacies')

plt.figure(figsize=(12, 6))
sns.boxplot(df)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(data=df, x='Glucose', kde=True)
plt.title('Distribution of Glucose')
# Out:
# Text(0.5, 1.0, 'Distribution of Glucose')

# %%
#question 2 

df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.isnull().value_counts()
# Out:
# Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI    DiabetesPedigreeFunction  Age    Outcome
# False        False    False          False          False    False  False                     False  False      768
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
def removal_box_plot(df, Glucose, threshold):
    sns.boxplot(df[Glucose])
    plt.title(f'Original Box Plot of {Glucose}')
    plt.show()
 
    removed_outliers = df[df[Glucose] <= threshold]
 
    sns.boxplot(removed_outliers[Glucose])
    plt.title(f'Box Plot without Outliers of {Glucose}')
    plt.show()
    return removed_outliers 
 
threshold_value = 250
removal_box_plot(df, 'Glucose', threshold_value)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#question 3 

X = df.iloc[::-1]
y = df['Outcome']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 303            5      115             98              0        0  52.9
# 544            1       88             78             29       76  32.0
# 374            2      122             52             43      158  36.2
# 1              1       85             66             29        0  26.6
# 197            3      107             62             13       48  22.9
# ..           ...      ...            ...            ...      ...   ...
# 696            3      169             74             19      125  29.9
# 661            1      199             76             43        0  42.9
# 497            2       81             72             15       76  30.1
# 332            1      180              0              0        0  43.3
# 665            1      112             80             45      132  34.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 303                     0.209   28        1
# ...

# %%
#question 4 

from sklearn.tree import DecisionTreeClassifier
treeclassifier=DecisionTreeClassifier()
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#question 5 

from sklearn.metrics import confusion_matrix,classification_report

clf = treeclassifier.fit(X_train, y_train)
predictions = clf.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=clf.classes_)
cm
# Out:
# array([[115,  53],
#        [ 61,  25]])

# %%
#question 6 

from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treeclassifier,filled=True)
# Out:
# [Text(0.6886224007561437, 0.9642857142857143, 'x[4] <= 107.0\ngini = 0.457\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.452859168241966, 0.8928571428571429, 'x[0] <= 3.5\ngini = 0.479\nsamples = 367\nvalue = [221, 146]'),
#  Text(0.2748109640831758, 0.8214285714285714, 'x[7] <= 30.5\ngini = 0.498\nsamples = 202\nvalue = [108, 94]'),
#  Text(0.21502835538752363, 0.75, 'x[5] <= 32.15\ngini = 0.487\nsamples = 165\nvalue = [96, 69]'),
#  Text(0.14083175803402648, 0.6785714285714286, 'x[5] <= 25.7\ngini = 0.499\nsamples = 108\nvalue = [56, 52]'),
#  Text(0.08506616257088846, 0.6071428571428571, 'x[1] <= 101.5\ngini = 0.457\nsamples = 51\nvalue = [33, 18]'),
#  Text(0.04158790170132325, 0.5357142857142857, 'x[5] <= 20.7\ngini = 0.494\nsamples = 36\nvalue = [20, 16]'),
#  Text(0.015122873345935728, 0.4642857142857143, 'x[2] <= 67.0\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.007561436672967864, 0.39285714285714285, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
# ...

# %%
#question 7
